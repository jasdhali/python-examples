# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./venv/lib/python3.10/site-packages (0.116.0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.10/site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.10/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./venv/lib/python3.10/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./venv/lib/python3.10/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.10/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv/lib/python3.10/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in ./venv/lib/python3.10/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./venv/lib/python3.10/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in ./venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import dotenv
print(dotenv.__file__)
# Out:
# /home/jaspal/practice/python-ws/venv/lib/python3.10/site-packages/dotenv/__init__.py

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path="/home/jaspal/practice/python-ws/.env")
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user","content":text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)
  

def chat(messages):
    message = client.messages.create(    
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []
# Add in the initial user question of "Define quantum computing in one sentence"
add_user_message(messages, "Define quantum conputing in one sentence")
# Pass the list of messages into 'chat' to get an answer
answer = chat( messages )
#Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)
#Add in the user's follow-up question
add_user_message(messages, "Write another sentence")
#Call chat again with the list of messages to get a final answer
answer = chat(messages)
answer
# Out:
# 'Unlike classical computers that use bits representing either 0 or 1, quantum computers use **quantum bits (qubits)** that can exist in multiple states simultaneously, enabling them to perform massive parallel calculations and tackle problems in fields like cryptography, drug discovery, and optimization that would take traditional computers millions of years to solve.'
